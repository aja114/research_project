# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import math
import copy

import numpy as np
import gym
import gym_keygrid
import pandas as pd

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.insert(1, "../")

# %%
from rl_research.utils import plot_policy, plot_states, plot_qtables, plot_state_freq, plot_scores

# %% [markdown]
# ### Environment and Optimal Value Function

# %%
from rl_research.algorithms.temporal_difference import td_learning, q_learning

# %%
env = gym.make('keygrid-v0', grid_length=5)
# Out:
# You are using the KeyGridSparse environment with length 5

# %%
plot_policy(env, env.opt_policy, title="Optimal Policy")

# %% [markdown]
# ### TD Learning using optimal policy

# %%
v_array = td_learning(env.opt_policy, env, display=False)
_ = plot_states(v_array, annot=v_array, title="Value function")

# %% [markdown]
# ### Q Learning

# %%
q_table = q_learning(env, display=False, num_episodes=50000)
q_policy = {x: env.actions[np.argmax(q_table[x])] for x in env.states}
_ = plot_policy(env, q_policy, "Q-Learning Policy")

# %% [markdown]
# ### Genetic Algorithm

# %%
from rl_research.algorithms.genetic_algo import train, get_best_agent

# %%
best_agents = train(env, 400)
# Out:
# ****************************************************************************************************
# TRAINING START
#
# Generation: 1 Score: 0
# Generation: 2 Score: 0
# Generation: 3 Score: 0
# Generation: 4 Score: 0
# Generation: 5 Score: 0
# Generation: 6 Score: 0
# Generation: 7 Score: 0
# Generation: 8 Score: 0
# Generation: 9 Score: 0
# Generation: 10 Score: 0
# Generation: 11 Score: 0
# Generation: 12 Score: 0
# Generation: 13 Score: 0
# Generation: 14 Score: 0
# Generation: 15 Score: 0
# Generation: 16 Score: 0
# Generation: 17 Score: 0
# Generation: 18 Score: 0
# Generation: 19 Score: 0
# Generation: 20 Score: 0
# Generation: 21 Score: 0
# Generation: 22 Score: 0
# Generation: 23 Score: 0
# Generation: 24 Score: 0
# Generation: 25 Score: 0
# Generation: 26 Score: 0
# Generation: 27 Score: 0
# Generation: 28 Score: 0
# Generation: 29 Score: 0
# Generation: 30 Score: 0
# Generation: 31 Score: 0
# Generation: 32 Score: 0
# Generation: 33 Score: 0
# Generation: 34 Score: 0
# Generation: 35 Score: 0
# Generation: 36 Score: 0
# Generation: 37 Score: 0
# Generation: 38 Score: 0
# Generation: 39 Score: 0
# Generation: 40 Score: 0
# Generation: 41 Score: 0
# Generation: 42 Score: 0
# Generation: 43 Score: 0
# Generation: 44 Score: 0
# Generation: 45 Score: 0
# Generation: 46 Score: 0
# Generation: 47 Score: 0
# Generation: 48 Score: 0
# Generation: 49 Score: 0
# Generation: 50 Score: 0
# Generation: 51 Score: 0
# Generation: 52 Score: 0
# Generation: 53 Score: 0
# Generation: 54 Score: 0
# Generation: 55 Score: 0
# Generation: 56 Score: 0
# Generation: 57 Score: 0
# Generation: 58 Score: 0
# Generation: 59 Score: 0
# Generation: 60 Score: 0
# Generation: 61 Score: 0
# Generation: 62 Score: 0
# Generation: 63 Score: 0
# Generation: 64 Score: 0
# Generation: 65 Score: 0
# Generation: 66 Score: 0
# Generation: 67 Score: 0
# Generation: 68 Score: 0
# Generation: 69 Score: 0
# Generation: 70 Score: 0
# Generation: 71 Score: 0
# Generation: 72 Score: 0
# Generation: 73 Score: 0
# Generation: 74 Score: 0
# Generation: 75 Score: 0
# Generation: 76 Score: 0
# Generation: 77 Score: 0
# Generation: 78 Score: 0
# Generation: 79 Score: 0
# Generation: 80 Score: 0
# Generation: 81 Score: 0
# Generation: 82 Score: 0
# Generation: 83 Score: 0
# Generation: 84 Score: 0
# Generation: 85 Score: 0
# Generation: 86 Score: 0
# Generation: 87 Score: 0
# Generation: 88 Score: 0
# Generation: 89 Score: 0
# Generation: 90 Score: 0
# Generation: 91 Score: 0
# Generation: 92 Score: 0
# Generation: 93 Score: 0
# Generation: 94 Score: 0
# Generation: 95 Score: 0
# Generation: 96 Score: 0
# Generation: 97 Score: 0
# Generation: 98 Score: 0
# Generation: 99 Score: 0
# Generation: 100 Score: 0
# Generation: 101 Score: 0
# Generation: 102 Score: 0
# Generation: 103 Score: 0
# Generation: 104 Score: 0
# Generation: 105 Score: 0
# Generation: 106 Score: 0
# Generation: 107 Score: 0
# Generation: 108 Score: 0
# Generation: 109 Score: 0
# Generation: 110 Score: 0
# Generation: 111 Score: 0
# Generation: 112 Score: 0
# Generation: 113 Score: 0
# Generation: 114 Score: 0
# Generation: 115 Score: 0
# Generation: 116 Score: 0
# Generation: 117 Score: 0
# Generation: 118 Score: 0
# Generation: 119 Score: 0
# Generation: 120 Score: 0
# Generation: 121 Score: 0
# Generation: 122 Score: 0
# Generation: 123 Score: 0
# Generation: 124 Score: 0
# Generation: 125 Score: 0
# Generation: 126 Score: 0
# Generation: 127 Score: 0
# Generation: 128 Score: 0
# Generation: 129 Score: 0
# Generation: 130 Score: 0
# Generation: 131 Score: 0
# Generation: 132 Score: 0
# Generation: 133 Score: 0
# Generation: 134 Score: 0
# Generation: 135 Score: 0
# Generation: 136 Score: 0
# Generation: 137 Score: 0
# Generation: 138 Score: 0
# Generation: 139 Score: 0
# Generation: 140 Score: 0
# Generation: 141 Score: 0
# Generation: 142 Score: 0
# Generation: 143 Score: 0
# Generation: 144 Score: 0
# Generation: 145 Score: 0
# Generation: 146 Score: 0
# Generation: 147 Score: 0
# Generation: 148 Score: 0
# Generation: 149 Score: 0
# Generation: 150 Score: 0
# Generation: 151 Score: 0
# Generation: 152 Score: 0
# Generation: 153 Score: 0
# Generation: 154 Score: 0
# Generation: 155 Score: 0
# Generation: 156 Score: 0
# Generation: 157 Score: 50
# Generation: 158 Score: 50
# Generation: 159 Score: 50
# Generation: 160 Score: 50
# Generation: 161 Score: 50
# Generation: 162 Score: 50
# Generation: 163 Score: 50
# Generation: 164 Score: 50
# Generation: 165 Score: 50
# Generation: 166 Score: 50
# Generation: 167 Score: 50
# Generation: 168 Score: 50
# Generation: 169 Score: 50
# Generation: 170 Score: 50
# Generation: 171 Score: 50
# Generation: 172 Score: 50
# Generation: 173 Score: 50
# Generation: 174 Score: 50
# Generation: 175 Score: 50
# Generation: 176 Score: 50
# Generation: 177 Score: 50
# Generation: 178 Score: 50
# Generation: 179 Score: 50
# Generation: 180 Score: 50
# Generation: 181 Score: 50
# Generation: 182 Score: 50
# Generation: 183 Score: 50
# Generation: 184 Score: 50
# Generation: 185 Score: 50
# Generation: 186 Score: 50
# Generation: 187 Score: 50
# Generation: 188 Score: 50
# Generation: 189 Score: 50
# Generation: 190 Score: 50
# Generation: 191 Score: 50
# Generation: 192 Score: 50
# Generation: 193 Score: 50
# Generation: 194 Score: 50
# Generation: 195 Score: 50
# Generation: 196 Score: 50
# Generation: 197 Score: 50
# Generation: 198 Score: 50
# Generation: 199 Score: 50
# Generation: 200 Score: 50
# Generation: 201 Score: 50
# Generation: 202 Score: 50
# Generation: 203 Score: 50
# Generation: 204 Score: 50
# Generation: 205 Score: 50
# Generation: 206 Score: 50
# Generation: 207 Score: 50
# Generation: 208 Score: 50
# Generation: 209 Score: 50
# Generation: 210 Score: 50
# Generation: 211 Score: 50
# Generation: 212 Score: 50
# Generation: 213 Score: 50
# Generation: 214 Score: 50
# Generation: 215 Score: 50
# Generation: 216 Score: 50
# Generation: 217 Score: 50
# Generation: 218 Score: 50
# Generation: 219 Score: 50
# Generation: 220 Score: 50
# Generation: 221 Score: 50
# Generation: 222 Score: 50
# Generation: 223 Score: 50
# Generation: 224 Score: 50
# Generation: 225 Score: 50
# Generation: 226 Score: 50
# Generation: 227 Score: 50
# Generation: 228 Score: 50
# Generation: 229 Score: 50
# Generation: 230 Score: 50
# Generation: 231 Score: 50
# Generation: 232 Score: 50
# Generation: 233 Score: 50
# Generation: 234 Score: 50
# Generation: 235 Score: 50
# Generation: 236 Score: 50
# Generation: 237 Score: 50
# Generation: 238 Score: 50
# Generation: 239 Score: 50
# Generation: 240 Score: 50
# Generation: 241 Score: 50
# Generation: 242 Score: 50
# Generation: 243 Score: 50
# Generation: 244 Score: 50
# Generation: 245 Score: 50
# Generation: 246 Score: 50
# Generation: 247 Score: 50
# Generation: 248 Score: 50
# Generation: 249 Score: 50
# Generation: 250 Score: 50
# Generation: 251 Score: 50
# Generation: 252 Score: 50
# Generation: 253 Score: 50
# Generation: 254 Score: 50
# Generation: 255 Score: 50
# Generation: 256 Score: 50
# Generation: 257 Score: 50
# Generation: 258 Score: 50
# Generation: 259 Score: 50
# Generation: 260 Score: 50
# Generation: 261 Score: 50
# Generation: 262 Score: 50
# Generation: 263 Score: 50
# Generation: 264 Score: 50
# Generation: 265 Score: 50
# Generation: 266 Score: 50
# Generation: 267 Score: 50
# Generation: 268 Score: 50
# Generation: 269 Score: 50
# Generation: 270 Score: 50
# Generation: 271 Score: 50
# Generation: 272 Score: 50
# Generation: 273 Score: 50
# Generation: 274 Score: 50
# Generation: 275 Score: 50
# Generation: 276 Score: 50
# Generation: 277 Score: 50
# Generation: 278 Score: 50
# Generation: 279 Score: 50
# Generation: 280 Score: 50
# Generation: 281 Score: 50
# Generation: 282 Score: 50
# Generation: 283 Score: 50
# Generation: 284 Score: 50
# Generation: 285 Score: 50
# Generation: 286 Score: 50
# Generation: 287 Score: 50
# Generation: 288 Score: 50
# Generation: 289 Score: 50
# Generation: 290 Score: 50
# Generation: 291 Score: 50
# Generation: 292 Score: 50
# Generation: 293 Score: 50
# Generation: 294 Score: 50
# Generation: 295 Score: 50
# Generation: 296 Score: 50
# Generation: 297 Score: 50
# Generation: 298 Score: 50
# Generation: 299 Score: 50
# Generation: 300 Score: 50
# Generation: 301 Score: 50
# Generation: 302 Score: 50
# Generation: 303 Score: 50
# Generation: 304 Score: 50
# Generation: 305 Score: 50
# Generation: 306 Score: 50
# Generation: 307 Score: 50
# Generation: 308 Score: 50
# Generation: 309 Score: 50
# Generation: 310 Score: 50
# Generation: 311 Score: 50
# Generation: 312 Score: 50
# Generation: 313 Score: 50
# Generation: 314 Score: 50
# Generation: 315 Score: 50
# Generation: 316 Score: 50
# Generation: 317 Score: 50
# Generation: 318 Score: 50
# Generation: 319 Score: 50
# Generation: 320 Score: 50
# Generation: 321 Score: 50
# Generation: 322 Score: 50
# Generation: 323 Score: 50
# Generation: 324 Score: 50
# Generation: 325 Score: 50
# Generation: 326 Score: 50
# Generation: 327 Score: 50
# Generation: 328 Score: 50
# Generation: 329 Score: 50
# Generation: 330 Score: 50
# Generation: 331 Score: 50
# Generation: 332 Score: 50
# Generation: 333 Score: 50
# Generation: 334 Score: 50
# Generation: 335 Score: 50
# Generation: 336 Score: 50
# Generation: 337 Score: 50
# Generation: 338 Score: 50
# Generation: 339 Score: 50
# Generation: 340 Score: 50
# Generation: 341 Score: 50
# Generation: 342 Score: 50
# Generation: 343 Score: 50
# Generation: 344 Score: 50
# Generation: 345 Score: 50
# Generation: 346 Score: 50
# Generation: 347 Score: 50
# Generation: 348 Score: 50
# Generation: 349 Score: 50
# Generation: 350 Score: 50
# Generation: 351 Score: 50
# Generation: 352 Score: 50
# Generation: 353 Score: 50
# Generation: 354 Score: 50
# Generation: 355 Score: 50
# Generation: 356 Score: 50
# Generation: 357 Score: 50
# Generation: 358 Score: 50
# Generation: 359 Score: 50
# Generation: 360 Score: 50
# Generation: 361 Score: 50
# Generation: 362 Score: 50
# Generation: 363 Score: 50
# Generation: 364 Score: 50
# Generation: 365 Score: 50
# Generation: 366 Score: 50
# Generation: 367 Score: 50
# Generation: 368 Score: 50
# Generation: 369 Score: 50
# Generation: 370 Score: 50
# Generation: 371 Score: 50
# Generation: 372 Score: 50
# Generation: 373 Score: 50
# Generation: 374 Score: 50
# Generation: 375 Score: 50
# Generation: 376 Score: 50
# Generation: 377 Score: 50
# Generation: 378 Score: 50
# Generation: 379 Score: 50
# Generation: 380 Score: 50
# Generation: 381 Score: 50
# Generation: 382 Score: 50
# Generation: 383 Score: 50
# Generation: 384 Score: 50
# Generation: 385 Score: 50
# Generation: 386 Score: 50
# Generation: 387 Score: 50
# Generation: 388 Score: 50
# Generation: 389 Score: 50
# Generation: 390 Score: 50
# Generation: 391 Score: 50
# Generation: 392 Score: 50
# Generation: 393 Score: 50
# Generation: 394 Score: 50
# Generation: 395 Score: 50
# Generation: 396 Score: 50
# Generation: 397 Score: 50
# Generation: 398 Score: 50
# Generation: 399 Score: 50
# Generation: 400 Score: 50
#
# ****************************************************************************************************
# TRAINING ENDED

# %%
policy  = {x: get_best_agent(best_agents).get_action(x) for x in env.states}
plot_policy(env, policy, "GA")

# %% [markdown]
# ### ES Algorithm

# %%
from rl_research.algorithms.env_strat import train

# %%
agent = train(env)
# Out:
# ****************************************************************************************************
# TRAINING START
#
# (array([0.]), array([100]))
# Generation: 0 Score: 0
# (array([0.]), array([100]))
# Generation: 1 Score: 0
# (array([0.]), array([100]))
# Generation: 2 Score: 0
# (array([0.]), array([100]))
# Generation: 3 Score: 0
# (array([0.]), array([100]))
# Generation: 4 Score: 0
# (array([0.]), array([100]))
# Generation: 5 Score: 0
# (array([0.]), array([100]))
# Generation: 6 Score: 0
# (array([0.]), array([100]))
# Generation: 7 Score: 0
# (array([0.]), array([100]))
# Generation: 8 Score: 0
# (array([0.]), array([100]))
# Generation: 9 Score: 0
# (array([0.]), array([100]))
# Generation: 10 Score: 0
# (array([0.]), array([100]))
# Generation: 11 Score: 0
# (array([0.]), array([100]))
# Generation: 12 Score: 0
# (array([0.]), array([100]))
# Generation: 13 Score: 0
# (array([0.]), array([100]))
# Generation: 14 Score: 0
# (array([0.]), array([100]))
# Generation: 15 Score: 0
# (array([0.]), array([100]))
# Generation: 16 Score: 0
# (array([0.]), array([100]))
# Generation: 17 Score: 0
# (array([0.]), array([100]))
# Generation: 18 Score: 0
# (array([0.]), array([100]))
# Generation: 19 Score: 0
# (array([0.]), array([100]))
# Generation: 20 Score: 0
# (array([0.]), array([100]))
# Generation: 21 Score: 0
# (array([0.]), array([100]))
# Generation: 22 Score: 0
# (array([0.]), array([100]))
# Generation: 23 Score: 0
# (array([0.]), array([100]))
# Generation: 24 Score: 0
# (array([0.]), array([100]))
# Generation: 25 Score: 0
# (array([0.]), array([100]))
# Generation: 26 Score: 0
# (array([0.]), array([100]))
# Generation: 27 Score: 0
# (array([0.]), array([100]))
# Generation: 28 Score: 0
# (array([0.]), array([100]))
# Generation: 29 Score: 0
# (array([0.]), array([100]))
# Generation: 30 Score: 0
# (array([0.]), array([100]))
# Generation: 31 Score: 0
# (array([0.]), array([100]))
# Generation: 32 Score: 0
# (array([0.]), array([100]))
# Generation: 33 Score: 0
# (array([0.]), array([100]))
# Generation: 34 Score: 0
# (array([0.]), array([100]))
# Generation: 35 Score: 0
# (array([0.]), array([100]))
# Generation: 36 Score: 0
# (array([0.]), array([100]))
# Generation: 37 Score: 0
# (array([0.]), array([100]))
# Generation: 38 Score: 0
# (array([0.]), array([100]))
# Generation: 39 Score: 0
# (array([0.]), array([100]))
# Generation: 40 Score: 0
# (array([0.]), array([100]))
# Generation: 41 Score: 0
# (array([0.]), array([100]))
# Generation: 42 Score: 0
# (array([0.]), array([100]))
# Generation: 43 Score: 0
# (array([0.]), array([100]))
# Generation: 44 Score: 0
# (array([0.]), array([100]))
# Generation: 45 Score: 0
# (array([0.]), array([100]))
# Generation: 46 Score: 0
# (array([0.]), array([100]))
# Generation: 47 Score: 0
# (array([0.]), array([100]))
# Generation: 48 Score: 0
# (array([0.]), array([100]))
# Generation: 49 Score: 0
# (array([0.]), array([100]))
# Generation: 50 Score: 0
# (array([0.]), array([100]))
# Generation: 51 Score: 0
# (array([0.]), array([100]))
# Generation: 52 Score: 0
# (array([0.]), array([100]))
# Generation: 53 Score: 0
# (array([0.]), array([100]))
# Generation: 54 Score: 0
# (array([0.]), array([100]))
# Generation: 55 Score: 0
# (array([0.]), array([100]))
# Generation: 56 Score: 0
# (array([0.]), array([100]))
# Generation: 57 Score: 0
# (array([0.]), array([100]))
# Generation: 58 Score: 0
# (array([0.]), array([100]))
# Generation: 59 Score: 0
# (array([0.]), array([100]))
# Generation: 60 Score: 0
# (array([0.]), array([100]))
# Generation: 61 Score: 0
# (array([0.]), array([100]))
# Generation: 62 Score: 0
# (array([0.]), array([100]))
# Generation: 63 Score: 0
# (array([0.]), array([100]))
# Generation: 64 Score: 0
# (array([0.]), array([100]))
# Generation: 65 Score: 0
# (array([0.]), array([100]))
# Generation: 66 Score: 0
# (array([0.]), array([100]))
# Generation: 67 Score: 0
# (array([0.]), array([100]))
# Generation: 68 Score: 0
# (array([0.]), array([100]))
# Generation: 69 Score: 0
# (array([0.]), array([100]))
# Generation: 70 Score: 0
# (array([0.]), array([100]))
# Generation: 71 Score: 0
# (array([0.]), array([100]))
# Generation: 72 Score: 0
# (array([0.]), array([100]))
# Generation: 73 Score: 0
# (array([0.]), array([100]))
# Generation: 74 Score: 0
# (array([0.]), array([100]))
# Generation: 75 Score: 0
# (array([0.]), array([100]))
# Generation: 76 Score: 0
# (array([0.]), array([100]))
# Generation: 77 Score: 0
# (array([0.]), array([100]))
# Generation: 78 Score: 0
# (array([0.]), array([100]))
# Generation: 79 Score: 0
# (array([0.]), array([100]))
# Generation: 80 Score: 0
# (array([0.]), array([100]))
# Generation: 81 Score: 0
# (array([0.]), array([100]))
# Generation: 82 Score: 0
# (array([0.]), array([100]))
# Generation: 83 Score: 0
# (array([0.]), array([100]))
# Generation: 84 Score: 0
# (array([0.]), array([100]))
# Generation: 85 Score: 0
# (array([0.]), array([100]))
# Generation: 86 Score: 0
# (array([0.]), array([100]))
# Generation: 87 Score: 0
# (array([0.]), array([100]))
# Generation: 88 Score: 0
# (array([0.]), array([100]))
# Generation: 89 Score: 0
# (array([0.]), array([100]))
# Generation: 90 Score: 0
# (array([0.]), array([100]))
# Generation: 91 Score: 0
# (array([0.]), array([100]))
# Generation: 92 Score: 0
# (array([0.]), array([100]))
# Generation: 93 Score: 0
# (array([0.]), array([100]))
# Generation: 94 Score: 0
# (array([0.]), array([100]))
# Generation: 95 Score: 0
# (array([0.]), array([100]))
# Generation: 96 Score: 0
# (array([0.]), array([100]))
# Generation: 97 Score: 0
# (array([0.]), array([100]))
# Generation: 98 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 99 Score: 0
# (array([0.]), array([100]))
# Generation: 100 Score: 0
# (array([0.]), array([100]))
# Generation: 101 Score: 0
# (array([0.]), array([100]))
# Generation: 102 Score: 0
# (array([0.]), array([100]))
# Generation: 103 Score: 0
# (array([0.]), array([100]))
# Generation: 104 Score: 0
# (array([0.]), array([100]))
# Generation: 105 Score: 0
# (array([0.]), array([100]))
# Generation: 106 Score: 0
# (array([0.]), array([100]))
# Generation: 107 Score: 0
# (array([0.]), array([100]))
# Generation: 108 Score: 0
# (array([0.]), array([100]))
# Generation: 109 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 110 Score: 0
# (array([0.]), array([100]))
# Generation: 111 Score: 0
# (array([0.]), array([100]))
# Generation: 112 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 113 Score: 0
# (array([0.]), array([100]))
# Generation: 114 Score: 0
# (array([0.]), array([100]))
# Generation: 115 Score: 0
# (array([0.]), array([100]))
# Generation: 116 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 117 Score: 0
# (array([0.]), array([100]))
# Generation: 118 Score: 0
# (array([0.]), array([100]))
# Generation: 119 Score: 0
# (array([0.]), array([100]))
# Generation: 120 Score: 0
# (array([0.]), array([100]))
# Generation: 121 Score: 0
# (array([0.]), array([100]))
# Generation: 122 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 123 Score: 50
# (array([ 0., 50.]), array([99,  1]))
# Generation: 124 Score: 50
# (array([ 0., 50.]), array([97,  3]))
# Generation: 125 Score: 0
# (array([ 0., 50.]), array([97,  3]))
# Generation: 126 Score: 50
# (array([0.]), array([100]))
# Generation: 127 Score: 50
# (array([ 0., 50.]), array([98,  2]))
# Generation: 128 Score: 0
# (array([ 0., 50.]), array([95,  5]))
# Generation: 129 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 130 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 131 Score: 0
# (array([ 0., 50.]), array([98,  2]))
# Generation: 132 Score: 0
# (array([ 0., 50.]), array([97,  3]))
# Generation: 133 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 134 Score: 0
# (array([0.]), array([100]))
# Generation: 135 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 136 Score: 50
# (array([ 0., 50.]), array([97,  3]))
# Generation: 137 Score: 0
# (array([ 0., 50.]), array([99,  1]))
# Generation: 138 Score: 0
# (array([ 0., 50.]), array([97,  3]))
# Generation: 139 Score: 50
# (array([ 0., 50.]), array([96,  4]))
# Generation: 140 Score: 50
# (array([ 0., 50.]), array([94,  6]))
# Generation: 141 Score: 50
# (array([ 0., 50.]), array([94,  6]))
# Generation: 142 Score: 50
# (array([ 0., 50.]), array([97,  3]))
# Generation: 143 Score: 50
# (array([ 0., 50.]), array([94,  6]))
# Generation: 144 Score: 50
# (array([ 0., 50.]), array([90, 10]))
# Generation: 145 Score: 50
# (array([ 0., 50.]), array([93,  7]))
# Generation: 146 Score: 50
# (array([ 0., 50.]), array([83, 17]))
# Generation: 147 Score: 50
# (array([ 0., 50.]), array([82, 18]))
# Generation: 148 Score: 50
# (array([ 0., 50.]), array([76, 24]))
# Generation: 149 Score: 0
# (array([ 0., 50.]), array([81, 19]))
# Generation: 150 Score: 50
# (array([ 0., 50.]), array([83, 17]))
# Generation: 151 Score: 0
# (array([ 0., 50.]), array([81, 19]))
# Generation: 152 Score: 50
# (array([ 0., 50.]), array([89, 11]))
# Generation: 153 Score: 50
# (array([ 0., 50.]), array([84, 16]))
# Generation: 154 Score: 50
# (array([ 0., 50.]), array([78, 22]))
# Generation: 155 Score: 0
# (array([ 0., 50.]), array([74, 26]))
# Generation: 156 Score: 50
# (array([ 0., 50.]), array([75, 25]))
# Generation: 157 Score: 50
# (array([ 0., 50.]), array([79, 21]))
# Generation: 158 Score: 50
# (array([ 0., 50.]), array([81, 19]))
# Generation: 159 Score: 0
# (array([ 0., 50.]), array([79, 21]))
# Generation: 160 Score: 50
# (array([ 0., 50.]), array([70, 30]))
# Generation: 161 Score: 0
# (array([ 0., 50.]), array([75, 25]))
# Generation: 162 Score: 50
# (array([ 0., 50.]), array([62, 38]))
# Generation: 163 Score: 0
# (array([ 0., 50.]), array([74, 26]))
# Generation: 164 Score: 50
# (array([ 0., 50.]), array([73, 27]))
# Generation: 165 Score: 0
# (array([ 0., 50.]), array([70, 30]))
# Generation: 166 Score: 50
# (array([ 0., 50.]), array([72, 28]))
# Generation: 167 Score: 0
# (array([ 0., 50.]), array([79, 21]))
# Generation: 168 Score: 0
# (array([ 0., 50.]), array([71, 29]))
# Generation: 169 Score: 0
# (array([ 0., 50.]), array([89, 11]))
# Generation: 170 Score: 50
# (array([ 0., 50.]), array([66, 34]))
# Generation: 171 Score: 0
# (array([ 0., 50.]), array([76, 24]))
# Generation: 172 Score: 0
# (array([ 0., 50.]), array([92,  8]))
# Generation: 173 Score: 50
# (array([ 0., 50.]), array([73, 27]))
# Generation: 174 Score: 50
# (array([ 0., 50.]), array([72, 28]))
# Generation: 175 Score: 0
# (array([ 0., 50.]), array([73, 27]))
# Generation: 176 Score: 0
# (array([ 0., 50.]), array([78, 22]))
# Generation: 177 Score: 0
# (array([ 0., 50.]), array([69, 31]))
# Generation: 178 Score: 0
# (array([ 0., 50.]), array([95,  5]))
# Generation: 179 Score: 50
# (array([ 0., 50.]), array([65, 35]))
# Generation: 180 Score: 50
# (array([ 0., 50.]), array([62, 38]))
# Generation: 181 Score: 50
# (array([ 0., 50.]), array([64, 36]))
# Generation: 182 Score: 0
# (array([ 0., 50.]), array([61, 39]))
# Generation: 183 Score: 0
# (array([ 0., 50.]), array([67, 33]))
# Generation: 184 Score: 0
# (array([ 0., 50.]), array([95,  5]))
# Generation: 185 Score: 50
# (array([ 0., 50.]), array([57, 43]))
# Generation: 186 Score: 0
# (array([ 0., 50.]), array([68, 32]))
# Generation: 187 Score: 0
# (array([ 0., 50.]), array([94,  6]))
# Generation: 188 Score: 50
# (array([ 0., 50.]), array([56, 44]))
# Generation: 189 Score: 50
# (array([ 0., 50.]), array([49, 51]))
# Generation: 190 Score: 50
# (array([ 0., 50.]), array([58, 42]))
# Generation: 191 Score: 0
# (array([ 0., 50.]), array([82, 18]))
# Generation: 192 Score: 0
# (array([ 0., 50.]), array([81, 19]))
# Generation: 193 Score: 0
# (array([ 0., 50.]), array([55, 45]))
# Generation: 194 Score: 0
# (array([ 0., 50.]), array([85, 15]))
# Generation: 195 Score: 50
# (array([ 0., 50.]), array([50, 50]))
# Generation: 196 Score: 50
# (array([ 0., 50.]), array([45, 55]))
# Generation: 197 Score: 50
# (array([ 0., 50.]), array([39, 61]))
# Generation: 198 Score: 50
# (array([ 0., 50.]), array([44, 56]))
# Generation: 199 Score: 0
# (array([ 0., 50.]), array([82, 18]))
# Generation: 200 Score: 0
# (array([ 0., 50.]), array([52, 48]))
# Generation: 201 Score: 0
# (array([ 0., 50.]), array([70, 30]))
# Generation: 202 Score: 0
# (array([ 0., 50.]), array([66, 34]))
# Generation: 203 Score: 0
# (array([ 0., 50.]), array([73, 27]))
# Generation: 204 Score: 0
# (array([ 0., 50.]), array([60, 40]))
# Generation: 205 Score: 0
# (array([ 0., 50.]), array([85, 15]))
# Generation: 206 Score: 0
# (array([ 0., 50.]), array([50, 50]))
# Generation: 207 Score: 0
# (array([ 0., 50.]), array([67, 33]))
# Generation: 208 Score: 0
# (array([ 0., 50.]), array([77, 23]))
# Generation: 209 Score: 0
# (array([ 0., 50.]), array([69, 31]))
# Generation: 210 Score: 0
# (array([ 0., 50.]), array([65, 35]))
# Generation: 211 Score: 0
# (array([ 0., 50.]), array([86, 14]))
# Generation: 212 Score: 50
# (array([ 0., 50.]), array([52, 48]))
# Generation: 213 Score: 0
# (array([ 0., 50.]), array([70, 30]))
# Generation: 214 Score: 50
# (array([ 0., 50.]), array([54, 46]))
# Generation: 215 Score: 0
# (array([ 0., 50.]), array([54, 46]))
# Generation: 216 Score: 0
# (array([ 0., 50.]), array([72, 28]))
# Generation: 217 Score: 0
# (array([ 0., 50.]), array([62, 38]))
# Generation: 218 Score: 0
# (array([ 0., 50.]), array([68, 32]))
# Generation: 219 Score: 0
# (array([ 0., 50.]), array([65, 35]))
# Generation: 220 Score: 0
# (array([ 0., 50.]), array([61, 39]))
# Generation: 221 Score: 0
# (array([ 0., 50.]), array([64, 36]))
# Generation: 222 Score: 50
# (array([ 0., 50.]), array([46, 54]))
# Generation: 223 Score: 0
# (array([ 0., 50.]), array([62, 38]))
# Generation: 224 Score: 0
# (array([ 0., 50.]), array([74, 26]))
# Generation: 225 Score: 50
# (array([ 0., 50.]), array([49, 51]))
# Generation: 226 Score: 0
# (array([ 0., 50.]), array([93,  7]))
# Generation: 227 Score: 50
# (array([ 0., 50.]), array([21, 79]))
# Generation: 228 Score: 0
# (array([ 0., 50.]), array([67, 33]))
# Generation: 229 Score: 50
# (array([ 0., 50.]), array([53, 47]))
# Generation: 230 Score: 0
# (array([ 0., 50.]), array([70, 30]))
# Generation: 231 Score: 0
# (array([ 0., 50.]), array([70, 30]))
# Generation: 232 Score: 50
# (array([ 0., 50.]), array([43, 57]))
# Generation: 233 Score: 50
# (array([ 0., 50.]), array([42, 58]))
# Generation: 234 Score: 0
# (array([ 0., 50.]), array([73, 27]))
# Generation: 235 Score: 0
# (array([ 0., 50.]), array([69, 31]))
# Generation: 236 Score: 0
# (array([ 0., 50.]), array([60, 40]))
# Generation: 237 Score: 50
# (array([ 0., 50.]), array([40, 60]))
# Generation: 238 Score: 0
# (array([ 0., 50.]), array([92,  8]))
# Generation: 239 Score: 50
# (array([ 0., 50.]), array([20, 80]))
# Generation: 240 Score: 50
# (array([ 0., 50.]), array([43, 57]))
# Generation: 241 Score: 50
# (array([ 0., 50.]), array([37, 63]))
# Generation: 242 Score: 50
# (array([ 0., 50.]), array([40, 60]))
# Generation: 243 Score: 0
# (array([ 0., 50.]), array([71, 29]))
# Generation: 244 Score: 50
# (array([ 0., 50.]), array([52, 48]))
# Generation: 245 Score: 0
# (array([ 0., 50.]), array([77, 23]))
# Generation: 246 Score: 50
# (array([ 0., 50.]), array([45, 55]))
# Generation: 247 Score: 0
# (array([ 0., 50.]), array([54, 46]))
# Generation: 248 Score: 50
# (array([ 0., 50.]), array([59, 41]))
# Generation: 249 Score: 50
# (array([ 0., 50.]), array([44, 56]))
# Generation: 250 Score: 0
# (array([ 0., 50.]), array([79, 21]))
# Generation: 251 Score: 50
# (array([ 0., 50.]), array([33, 67]))
# Generation: 252 Score: 50
# (array([ 0., 50.]), array([36, 64]))
# Generation: 253 Score: 0
# (array([ 0., 50.]), array([62, 38]))
# Generation: 254 Score: 50
# (array([ 0., 50.]), array([46, 54]))
# Generation: 255 Score: 0
# (array([ 0., 50.]), array([58, 42]))
# Generation: 256 Score: 50
# (array([ 0., 50.]), array([41, 59]))
# Generation: 257 Score: 0
# (array([ 0., 50.]), array([75, 25]))
# Generation: 258 Score: 50
# (array([ 0., 50.]), array([22, 78]))
# Generation: 259 Score: 0
# (array([ 0., 50.]), array([84, 16]))
# Generation: 260 Score: 50
# (array([ 0., 50.]), array([29, 71]))
# Generation: 261 Score: 0
# (array([ 0., 50.]), array([65, 35]))
# Generation: 262 Score: 0
# (array([ 0., 50.]), array([76, 24]))
# Generation: 263 Score: 50
# (array([ 0., 50.]), array([30, 70]))
# Generation: 264 Score: 0
# (array([ 0., 50.]), array([74, 26]))
# Generation: 265 Score: 50
# (array([ 0., 50.]), array([34, 66]))
# Generation: 266 Score: 0
# (array([ 0., 50.]), array([85, 15]))
# Generation: 267 Score: 50
# (array([ 0., 50.]), array([15, 85]))
# Generation: 268 Score: 50
# (array([ 0., 50.]), array([33, 67]))
# Generation: 269 Score: 0
# (array([ 0., 50.]), array([84, 16]))
# Generation: 270 Score: 50
# (array([ 0., 50.]), array([45, 55]))
# Generation: 271 Score: 0
# (array([ 0., 50.]), array([75, 25]))
# Generation: 272 Score: 0
# (array([ 0., 50.]), array([52, 48]))
# Generation: 273 Score: 0
# (array([ 0., 50.]), array([71, 29]))
# Generation: 274 Score: 50
# (array([ 0., 50.]), array([47, 53]))
# Generation: 275 Score: 0
# (array([ 0., 50.]), array([84, 16]))
# Generation: 276 Score: 50
# (array([ 0., 50.]), array([15, 85]))
# Generation: 277 Score: 0
# (array([ 0., 50.]), array([61, 39]))
# Generation: 278 Score: 50
# (array([ 0., 50.]), array([40, 60]))
# Generation: 279 Score: 0
# (array([ 0., 50.]), array([75, 25]))
# Generation: 280 Score: 50
# (array([ 0., 50.]), array([37, 63]))
# Generation: 281 Score: 0
# (array([ 0., 50.]), array([59, 41]))
# Generation: 282 Score: 0
# (array([ 0., 50.]), array([62, 38]))
# Generation: 283 Score: 0
# (array([ 0., 50.]), array([57, 43]))
# Generation: 284 Score: 0
# (array([ 0., 50.]), array([80, 20]))
# Generation: 285 Score: 50
# (array([ 0., 50.]), array([34, 66]))
# Generation: 286 Score: 0
# (array([ 0., 50.]), array([85, 15]))
# Generation: 287 Score: 50
# (array([ 0., 50.]), array([14, 86]))
# Generation: 288 Score: 0
# (array([ 0., 50.]), array([60, 40]))
# Generation: 289 Score: 0
# (array([ 0., 50.]), array([63, 37]))
# Generation: 290 Score: 50
# (array([ 0., 50.]), array([38, 62]))
# Generation: 291 Score: 0
# (array([ 0., 50.]), array([69, 31]))
# Generation: 292 Score: 50
# (array([ 0., 50.]), array([43, 57]))
# Generation: 293 Score: 0
# (array([ 0., 50.]), array([64, 36]))
# Generation: 294 Score: 50
# (array([ 0., 50.]), array([48, 52]))
# Generation: 295 Score: 50
# (array([ 0., 50.]), array([23, 77]))
# Generation: 296 Score: 0
# (array([ 0., 50.]), array([64, 36]))
# Generation: 297 Score: 50
# (array([ 0., 50.]), array([18, 82]))
# Generation: 298 Score: 50
# (array([ 0., 50.]), array([47, 53]))
# Generation: 299 Score: 50
#
# ****************************************************************************************************
# TRAINING ENDED

# %%
agent.get_policy()
agent.policy
plot_policy(env, agent.policy, "ES")

# %% [markdown]
# ### REINFORCE

# %%
from rl_research.algorithms.reinforce_baseline import train
L = 150
logs = True

# %%
agent = train(env, L, logs=logs)
# Out:
# ****************************************************************************************************
# TRAINING START
#
#
# Iteration:  0
# (0, 0) probas:  [0.33 0.33 0.33]
# (0, 1) probas:  [0.34 0.33 0.33]
# (1, 0) probas:  [0.33 0.33 0.33]
# (1, 1) probas:  [0.33 0.33 0.33]
# (2, 0) probas:  [0.34 0.33 0.34]
# (2, 1) probas:  [0.33 0.33 0.33]
# (3, 0) probas:  [0.34 0.33 0.34]
# (3, 1) probas:  [0.33 0.33 0.34]
# (4, 0) probas:  [0.34 0.32 0.34]
# (4, 1) probas:  [0.33 0.33 0.34]
# Score: 0
# % of visited states: 50.0%
#
# Iteration:  1
# Score: 0
# % of visited states: 50.0%
#
# Iteration:  2
# Score: 0
# % of visited states: 50.0%
#
# Iteration:  3
# Score: 0
# % of visited states: 60.0%
#
# Iteration:  4
# Score: 0
# % of visited states: 60.0%
#
# Iteration:  5
# Score: 0
# % of visited states: 60.0%
#
# Iteration:  6
# Score: 50
# % of visited states: 70.0%
#
# Iteration:  7
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  8
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  9
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  10
# (0, 0) probas:  [0.33 0.33 0.33]
# (0, 1) probas:  [0.36 0.35 0.29]
# (1, 0) probas:  [0.33 0.33 0.34]
# (1, 1) probas:  [0.36 0.35 0.28]
# (2, 0) probas:  [0.33 0.33 0.34]
# (2, 1) probas:  [0.37 0.35 0.29]
# (3, 0) probas:  [0.33 0.32 0.34]
# (3, 1) probas:  [0.37 0.34 0.29]
# (4, 0) probas:  [0.34 0.32 0.34]
# (4, 1) probas:  [0.37 0.34 0.3 ]
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  11
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  12
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  13
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  14
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  15
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  16
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  17
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  18
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  19
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  20
# (0, 0) probas:  [0.33 0.33 0.33]
# (0, 1) probas:  [0.36 0.35 0.29]
# (1, 0) probas:  [0.33 0.33 0.34]
# (1, 1) probas:  [0.36 0.35 0.28]
# (2, 0) probas:  [0.33 0.33 0.34]
# (2, 1) probas:  [0.37 0.35 0.29]
# (3, 0) probas:  [0.33 0.32 0.34]
# (3, 1) probas:  [0.37 0.34 0.29]
# (4, 0) probas:  [0.34 0.32 0.34]
# (4, 1) probas:  [0.37 0.34 0.3 ]
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  21
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  22
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  23
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  24
# Score: 0
# % of visited states: 90.0%
#
# Iteration:  25
# Score: 0
# % of visited states: 90.0%
#
# Iteration:  26
# Score: 0
# % of visited states: 90.0%
#
# Iteration:  27
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  28
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  29
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  30
# (0, 0) probas:  [0.36 0.29 0.35]
# (0, 1) probas:  [0.46 0.28 0.26]
# (1, 0) probas:  [0.35 0.29 0.36]
# (1, 1) probas:  [0.47 0.28 0.25]
# (2, 0) probas:  [0.36 0.29 0.35]
# (2, 1) probas:  [0.49 0.27 0.24]
# (3, 0) probas:  [0.36 0.29 0.35]
# (3, 1) probas:  [0.49 0.26 0.24]
# (4, 0) probas:  [0.37 0.29 0.35]
# (4, 1) probas:  [0.49 0.26 0.25]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  31
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  32
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  33
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  34
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  35
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  36
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  37
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  38
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  39
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  40
# (0, 0) probas:  [0.32 0.32 0.36]
# (0, 1) probas:  [0.4  0.33 0.26]
# (1, 0) probas:  [0.31 0.33 0.36]
# (1, 1) probas:  [0.41 0.34 0.25]
# (2, 0) probas:  [0.31 0.33 0.36]
# (2, 1) probas:  [0.41 0.34 0.25]
# (3, 0) probas:  [0.31 0.34 0.35]
# (3, 1) probas:  [0.41 0.34 0.24]
# (4, 0) probas:  [0.31 0.35 0.35]
# (4, 1) probas:  [0.41 0.35 0.25]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  41
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  42
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  43
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  44
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  45
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  46
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  47
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  48
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  49
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  50
# (0, 0) probas:  [0.34 0.31 0.35]
# (0, 1) probas:  [0.43 0.32 0.25]
# (1, 0) probas:  [0.32 0.32 0.36]
# (1, 1) probas:  [0.43 0.32 0.24]
# (2, 0) probas:  [0.32 0.33 0.35]
# (2, 1) probas:  [0.45 0.32 0.23]
# (3, 0) probas:  [0.32 0.33 0.34]
# (3, 1) probas:  [0.45 0.32 0.23]
# (4, 0) probas:  [0.33 0.34 0.33]
# (4, 1) probas:  [0.45 0.32 0.23]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  51
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  52
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  53
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  54
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  55
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  56
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  57
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  58
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  59
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  60
# (0, 0) probas:  [0.36 0.27 0.36]
# (0, 1) probas:  [0.5  0.24 0.27]
# (1, 0) probas:  [0.35 0.27 0.38]
# (1, 1) probas:  [0.51 0.23 0.26]
# (2, 0) probas:  [0.35 0.27 0.38]
# (2, 1) probas:  [0.53 0.23 0.25]
# (3, 0) probas:  [0.35 0.28 0.37]
# (3, 1) probas:  [0.53 0.22 0.25]
# (4, 0) probas:  [0.36 0.28 0.36]
# (4, 1) probas:  [0.53 0.22 0.25]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  61
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  62
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  63
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  64
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  65
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  66
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  67
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  68
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  69
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  70
# (0, 0) probas:  [0.27 0.3  0.43]
# (0, 1) probas:  [0.45 0.24 0.31]
# (1, 0) probas:  [0.26 0.3  0.44]
# (1, 1) probas:  [0.46 0.23 0.31]
# (2, 0) probas:  [0.25 0.3  0.44]
# (2, 1) probas:  [0.46 0.23 0.31]
# (3, 0) probas:  [0.25 0.31 0.44]
# (3, 1) probas:  [0.46 0.23 0.31]
# (4, 0) probas:  [0.25 0.31 0.44]
# (4, 1) probas:  [0.45 0.23 0.32]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  71
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  72
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  73
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  74
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  75
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  76
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  77
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  78
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  79
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  80
# (0, 0) probas:  [0.3  0.31 0.39]
# (0, 1) probas:  [0.6  0.19 0.21]
# (1, 0) probas:  [0.29 0.32 0.39]
# (1, 1) probas:  [0.62 0.18 0.2 ]
# (2, 0) probas:  [0.3  0.33 0.38]
# (2, 1) probas:  [0.64 0.18 0.19]
# (3, 0) probas:  [0.31 0.33 0.36]
# (3, 1) probas:  [0.65 0.17 0.18]
# (4, 0) probas:  [0.32 0.33 0.35]
# (4, 1) probas:  [0.65 0.18 0.17]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  81
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  82
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  83
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  84
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  85
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  86
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  87
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  88
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  89
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  90
# (0, 0) probas:  [0.35 0.29 0.36]
# (0, 1) probas:  [0.67 0.16 0.16]
# (1, 0) probas:  [0.35 0.3  0.35]
# (1, 1) probas:  [0.7  0.15 0.15]
# (2, 0) probas:  [0.36 0.3  0.33]
# (2, 1) probas:  [0.72 0.14 0.13]
# (3, 0) probas:  [0.38 0.31 0.31]
# (3, 1) probas:  [0.74 0.14 0.12]
# (4, 0) probas:  [0.4  0.31 0.29]
# (4, 1) probas:  [0.75 0.13 0.11]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  91
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  92
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  93
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  94
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  95
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  96
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  97
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  98
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  99
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  100
# (0, 0) probas:  [0.3  0.33 0.38]
# (0, 1) probas:  [0.62 0.2  0.17]
# (1, 0) probas:  [0.27 0.35 0.38]
# (1, 1) probas:  [0.65 0.19 0.16]
# (2, 0) probas:  [0.27 0.36 0.37]
# (2, 1) probas:  [0.67 0.18 0.15]
# (3, 0) probas:  [0.28 0.37 0.35]
# (3, 1) probas:  [0.68 0.18 0.14]
# (4, 0) probas:  [0.29 0.38 0.33]
# (4, 1) probas:  [0.68 0.18 0.14]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  101
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  102
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  103
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  104
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  105
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  106
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  107
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  108
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  109
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  110
# (0, 0) probas:  [0.22 0.4  0.38]
# (0, 1) probas:  [0.39 0.43 0.17]
# (1, 0) probas:  [0.2  0.43 0.38]
# (1, 1) probas:  [0.39 0.45 0.16]
# (2, 0) probas:  [0.18 0.46 0.36]
# (2, 1) probas:  [0.37 0.48 0.15]
# (3, 0) probas:  [0.18 0.49 0.33]
# (3, 1) probas:  [0.36 0.5  0.14]
# (4, 0) probas:  [0.17 0.52 0.31]
# (4, 1) probas:  [0.33 0.53 0.14]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  111
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  112
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  113
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  114
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  115
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  116
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  117
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  118
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  119
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  120
# (0, 0) probas:  [0.2  0.34 0.46]
# (0, 1) probas:  [0.5  0.34 0.16]
# (1, 0) probas:  [0.17 0.35 0.47]
# (1, 1) probas:  [0.51 0.35 0.14]
# (2, 0) probas:  [0.17 0.38 0.45]
# (2, 1) probas:  [0.52 0.35 0.13]
# (3, 0) probas:  [0.16 0.42 0.42]
# (3, 1) probas:  [0.51 0.36 0.12]
# (4, 0) probas:  [0.16 0.45 0.39]
# (4, 1) probas:  [0.49 0.39 0.12]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  121
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  122
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  123
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  124
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  125
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  126
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  127
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  128
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  129
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  130
# (0, 0) probas:  [0.29 0.27 0.44]
# (0, 1) probas:  [0.72 0.17 0.11]
# (1, 0) probas:  [0.29 0.28 0.43]
# (1, 1) probas:  [0.75 0.16 0.09]
# (2, 0) probas:  [0.32 0.3  0.38]
# (2, 1) probas:  [0.78 0.15 0.07]
# (3, 0) probas:  [0.35 0.31 0.34]
# (3, 1) probas:  [0.8  0.14 0.06]
# (4, 0) probas:  [0.39 0.32 0.3 ]
# (4, 1) probas:  [0.81 0.13 0.05]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  131
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  132
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  133
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  134
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  135
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  136
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  137
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  138
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  139
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  140
# (0, 0) probas:  [0.21 0.26 0.53]
# (0, 1) probas:  [0.71 0.18 0.11]
# (1, 0) probas:  [0.2  0.27 0.53]
# (1, 1) probas:  [0.75 0.16 0.09]
# (2, 0) probas:  [0.21 0.29 0.49]
# (2, 1) probas:  [0.78 0.15 0.08]
# (3, 0) probas:  [0.23 0.32 0.45]
# (3, 1) probas:  [0.79 0.14 0.06]
# (4, 0) probas:  [0.26 0.34 0.4 ]
# (4, 1) probas:  [0.8  0.14 0.06]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  141
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  142
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  143
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  144
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  145
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  146
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  147
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  148
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  149
# Score: 50
# % of visited states: 100.0%
#
# ****************************************************************************************************
# TRAINING ENDED

# %%
plot_scores(agent.scores, window_size=100)
agent.get_policy()
plot_policy(env, agent.pi, "REINFORCE")
plot_state_freq(agent.state_freq)
agent.get_proba()
# Out:
# {(0, 0): array([0.11507737, 0.4365727 , 0.44834986], dtype=float32),
#  (0, 1): array([0.8961985 , 0.06451503, 0.03928651], dtype=float32),
#  (1, 0): array([0.10690247, 0.4846252 , 0.40847236], dtype=float32),
#  (1, 1): array([0.9285642 , 0.04675285, 0.02468297], dtype=float32),
#  (2, 0): array([0.11853611, 0.55644244, 0.32502142], dtype=float32),
#  (2, 1): array([0.9474922 , 0.03659103, 0.01591678], dtype=float32),
#  (3, 0): array([0.14905258, 0.61122555, 0.23972185], dtype=float32),
#  (3, 1): array([0.95793545, 0.03153686, 0.01052776], dtype=float32),
#  (4, 0): array([0.19018765, 0.6384643 , 0.17134805], dtype=float32),
#  (4, 1): array([0.9641307 , 0.02883968, 0.00702969], dtype=float32)}

# %% [markdown]
# ### Reinforce count state exploration

# %%
from rl_research.algorithms.reinforce_count_states import train

# %%
agent = train(env, L, logs=logs)
# Out:
# ****************************************************************************************************
# TRAINING START
#
#
# Iteration:  0
# (0, 0) probas:  [0.33 0.33 0.33]
# (0, 1) probas:  [0.37 0.34 0.3 ]
# (1, 0) probas:  [0.34 0.33 0.33]
# (1, 1) probas:  [0.36 0.34 0.3 ]
# (2, 0) probas:  [0.34 0.33 0.32]
# (2, 1) probas:  [0.36 0.34 0.29]
# (3, 0) probas:  [0.34 0.34 0.32]
# (3, 1) probas:  [0.36 0.34 0.29]
# (4, 0) probas:  [0.35 0.34 0.32]
# (4, 1) probas:  [0.37 0.35 0.29]
# Score: 0
# % of visited states: 40.0%
#
# Iteration:  1
# Score: 0
# % of visited states: 90.0%
#
# Iteration:  2
# Score: 0
# % of visited states: 90.0%
#
# Iteration:  3
# Score: 0
# % of visited states: 90.0%
#
# Iteration:  4
# Score: 0
# % of visited states: 90.0%
#
# Iteration:  5
# Score: 0
# % of visited states: 90.0%
#
# Iteration:  6
# Score: 50
# % of visited states: 90.0%
#
# Iteration:  7
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  8
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  9
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  10
# (0, 0) probas:  [0.36 0.32 0.32]
# (0, 1) probas:  [0.45 0.29 0.26]
# (1, 0) probas:  [0.35 0.32 0.32]
# (1, 1) probas:  [0.45 0.3  0.26]
# (2, 0) probas:  [0.35 0.33 0.32]
# (2, 1) probas:  [0.45 0.3  0.25]
# (3, 0) probas:  [0.36 0.33 0.31]
# (3, 1) probas:  [0.45 0.3  0.25]
# (4, 0) probas:  [0.36 0.34 0.3 ]
# (4, 1) probas:  [0.45 0.3  0.25]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  11
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  12
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  13
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  14
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  15
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  16
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  17
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  18
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  19
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  20
# (0, 0) probas:  [0.29 0.39 0.32]
# (0, 1) probas:  [0.36 0.4  0.23]
# (1, 0) probas:  [0.28 0.41 0.32]
# (1, 1) probas:  [0.36 0.42 0.22]
# (2, 0) probas:  [0.27 0.43 0.3 ]
# (2, 1) probas:  [0.35 0.43 0.22]
# (3, 0) probas:  [0.27 0.44 0.29]
# (3, 1) probas:  [0.34 0.45 0.21]
# (4, 0) probas:  [0.27 0.46 0.28]
# (4, 1) probas:  [0.34 0.46 0.2 ]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  21
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  22
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  23
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  24
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  25
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  26
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  27
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  28
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  29
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  30
# (0, 0) probas:  [0.3  0.36 0.33]
# (0, 1) probas:  [0.42 0.37 0.21]
# (1, 0) probas:  [0.3  0.37 0.33]
# (1, 1) probas:  [0.42 0.38 0.2 ]
# (2, 0) probas:  [0.3  0.39 0.31]
# (2, 1) probas:  [0.42 0.4  0.19]
# (3, 0) probas:  [0.3 0.4 0.3]
# (3, 1) probas:  [0.41 0.41 0.18]
# (4, 0) probas:  [0.31 0.41 0.29]
# (4, 1) probas:  [0.41 0.42 0.17]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  31
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  32
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  33
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  34
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  35
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  36
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  37
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  38
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  39
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  40
# (0, 0) probas:  [0.28 0.4  0.32]
# (0, 1) probas:  [0.38 0.45 0.17]
# (1, 0) probas:  [0.27 0.43 0.3 ]
# (1, 1) probas:  [0.37 0.47 0.16]
# (2, 0) probas:  [0.27 0.45 0.28]
# (2, 1) probas:  [0.37 0.49 0.15]
# (3, 0) probas:  [0.27 0.47 0.26]
# (3, 1) probas:  [0.36 0.51 0.14]
# (4, 0) probas:  [0.27 0.49 0.24]
# (4, 1) probas:  [0.35 0.52 0.13]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  41
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  42
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  43
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  44
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  45
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  46
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  47
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  48
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  49
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  50
# (0, 0) probas:  [0.3  0.31 0.39]
# (0, 1) probas:  [0.57 0.29 0.14]
# (1, 0) probas:  [0.3  0.32 0.38]
# (1, 1) probas:  [0.58 0.3  0.12]
# (2, 0) probas:  [0.31 0.34 0.35]
# (2, 1) probas:  [0.58 0.31 0.11]
# (3, 0) probas:  [0.33 0.35 0.32]
# (3, 1) probas:  [0.58 0.32 0.1 ]
# (4, 0) probas:  [0.34 0.37 0.29]
# (4, 1) probas:  [0.58 0.33 0.09]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  51
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  52
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  53
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  54
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  55
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  56
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  57
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  58
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  59
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  60
# (0, 0) probas:  [0.32 0.24 0.44]
# (0, 1) probas:  [0.67 0.16 0.17]
# (1, 0) probas:  [0.32 0.23 0.45]
# (1, 1) probas:  [0.69 0.16 0.15]
# (2, 0) probas:  [0.34 0.23 0.43]
# (2, 1) probas:  [0.7  0.16 0.14]
# (3, 0) probas:  [0.36 0.23 0.41]
# (3, 1) probas:  [0.71 0.15 0.13]
# (4, 0) probas:  [0.39 0.23 0.38]
# (4, 1) probas:  [0.72 0.15 0.13]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  61
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  62
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  63
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  64
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  65
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  66
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  67
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  68
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  69
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  70
# (0, 0) probas:  [0.26 0.26 0.49]
# (0, 1) probas:  [0.52 0.25 0.23]
# (1, 0) probas:  [0.24 0.25 0.51]
# (1, 1) probas:  [0.53 0.26 0.22]
# (2, 0) probas:  [0.23 0.25 0.52]
# (2, 1) probas:  [0.53 0.26 0.21]
# (3, 0) probas:  [0.23 0.25 0.52]
# (3, 1) probas:  [0.53 0.26 0.21]
# (4, 0) probas:  [0.24 0.26 0.51]
# (4, 1) probas:  [0.52 0.26 0.22]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  71
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  72
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  73
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  74
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  75
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  76
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  77
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  78
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  79
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  80
# (0, 0) probas:  [0.19 0.3  0.51]
# (0, 1) probas:  [0.54 0.33 0.13]
# (1, 0) probas:  [0.18 0.3  0.52]
# (1, 1) probas:  [0.55 0.33 0.11]
# (2, 0) probas:  [0.18 0.32 0.49]
# (2, 1) probas:  [0.55 0.35 0.1 ]
# (3, 0) probas:  [0.19 0.35 0.46]
# (3, 1) probas:  [0.54 0.36 0.09]
# (4, 0) probas:  [0.2  0.38 0.42]
# (4, 1) probas:  [0.53 0.38 0.09]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  81
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  82
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  83
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  84
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  85
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  86
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  87
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  88
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  89
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  90
# (0, 0) probas:  [0.27 0.29 0.44]
# (0, 1) probas:  [0.71 0.22 0.06]
# (1, 0) probas:  [0.28 0.31 0.41]
# (1, 1) probas:  [0.73 0.22 0.05]
# (2, 0) probas:  [0.31 0.34 0.34]
# (2, 1) probas:  [0.74 0.22 0.04]
# (3, 0) probas:  [0.35 0.37 0.28]
# (3, 1) probas:  [0.74 0.22 0.03]
# (4, 0) probas:  [0.38 0.39 0.23]
# (4, 1) probas:  [0.75 0.23 0.03]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  91
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  92
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  93
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  94
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  95
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  96
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  97
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  98
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  99
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  100
# (0, 0) probas:  [0.25 0.35 0.4 ]
# (0, 1) probas:  [0.82 0.15 0.03]
# (1, 0) probas:  [0.25 0.4  0.35]
# (1, 1) probas:  [0.84 0.14 0.02]
# (2, 0) probas:  [0.28 0.45 0.28]
# (2, 1) probas:  [0.85 0.14 0.02]
# (3, 0) probas:  [0.3  0.48 0.21]
# (3, 1) probas:  [0.85 0.14 0.01]
# (4, 0) probas:  [0.33 0.51 0.16]
# (4, 1) probas:  [0.85 0.14 0.01]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  101
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  102
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  103
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  104
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  105
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  106
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  107
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  108
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  109
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  110
# (0, 0) probas:  [0.2  0.31 0.49]
# (0, 1) probas:  [0.73 0.22 0.05]
# (1, 0) probas:  [0.19 0.35 0.45]
# (1, 1) probas:  [0.74 0.22 0.04]
# (2, 0) probas:  [0.2  0.41 0.39]
# (2, 1) probas:  [0.74 0.22 0.04]
# (3, 0) probas:  [0.22 0.46 0.32]
# (3, 1) probas:  [0.73 0.24 0.03]
# (4, 0) probas:  [0.23 0.51 0.26]
# (4, 1) probas:  [0.72 0.25 0.03]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  111
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  112
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  113
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  114
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  115
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  116
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  117
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  118
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  119
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  120
# (0, 0) probas:  [0.3  0.33 0.37]
# (0, 1) probas:  [0.85 0.13 0.02]
# (1, 0) probas:  [0.28 0.38 0.34]
# (1, 1) probas:  [0.86 0.13 0.01]
# (2, 0) probas:  [0.28 0.44 0.28]
# (2, 1) probas:  [0.86 0.12 0.01]
# (3, 0) probas:  [0.28 0.5  0.22]
# (3, 1) probas:  [0.86 0.13 0.01]
# (4, 0) probas:  [0.29 0.54 0.17]
# (4, 1) probas:  [0.85 0.14 0.01]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  121
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  122
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  123
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  124
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  125
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  126
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  127
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  128
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  129
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  130
# (0, 0) probas:  [0.24 0.37 0.39]
# (0, 1) probas:  [0.86 0.12 0.02]
# (1, 0) probas:  [0.23 0.43 0.35]
# (1, 1) probas:  [0.87 0.12 0.02]
# (2, 0) probas:  [0.22 0.5  0.28]
# (2, 1) probas:  [0.87 0.12 0.01]
# (3, 0) probas:  [0.23 0.56 0.21]
# (3, 1) probas:  [0.86 0.13 0.01]
# (4, 0) probas:  [0.23 0.61 0.16]
# (4, 1) probas:  [0.85 0.15 0.01]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  131
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  132
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  133
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  134
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  135
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  136
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  137
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  138
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  139
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  140
# (0, 0) probas:  [0.21 0.35 0.44]
# (0, 1) probas:  [0.86 0.12 0.02]
# (1, 0) probas:  [0.2  0.41 0.38]
# (1, 1) probas:  [0.87 0.11 0.02]
# (2, 0) probas:  [0.22 0.48 0.29]
# (2, 1) probas:  [0.88 0.11 0.01]
# (3, 0) probas:  [0.25 0.54 0.21]
# (3, 1) probas:  [0.88 0.11 0.01]
# (4, 0) probas:  [0.27 0.58 0.15]
# (4, 1) probas:  [0.87 0.12 0.01]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  141
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  142
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  143
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  144
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  145
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  146
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  147
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  148
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  149
# Score: 0
# % of visited states: 100.0%
#
# ****************************************************************************************************
# TRAINING ENDED

# %%
plot_scores(agent.scores)
agent.get_policy()
plot_policy(env, agent.pi, "REINFORCE States Count")
plot_state_freq(agent.state_freq)
agent.get_proba()
# Out:
# 100.0

# %% [markdown]
# ### Reinforce count seq exploration

# %%
from rl_research.algorithms.reinforce_count_seq import train

# %%
agent = train(env, L, logs=logs)
# Out:
# ****************************************************************************************************
# TRAINING START
#
#
# Iteration:  0
# (0, 0) probas:  [0.33 0.33 0.33]
# (0, 1) probas:  [0.37 0.3  0.33]
# (1, 0) probas:  [0.33 0.34 0.33]
# (1, 1) probas:  [0.36 0.31 0.33]
# (2, 0) probas:  [0.33 0.34 0.33]
# (2, 1) probas:  [0.36 0.31 0.34]
# (3, 0) probas:  [0.33 0.34 0.33]
# (3, 1) probas:  [0.35 0.31 0.33]
# (4, 0) probas:  [0.33 0.34 0.33]
# (4, 1) probas:  [0.35 0.31 0.33]
# Score: 0
# % of visited states: 30.0%
#
# Iteration:  1
# Score: 50
# % of visited states: 60.0%
#
# Iteration:  2
# Score: 0
# % of visited states: 60.0%
#
# Iteration:  3
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  4
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  5
# Score: 50
# % of visited states: 80.0%
#
# Iteration:  6
# Score: 0
# % of visited states: 80.0%
#
# Iteration:  7
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  8
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  9
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  10
# (0, 0) probas:  [0.33 0.37 0.3 ]
# (0, 1) probas:  [0.47 0.31 0.22]
# (1, 0) probas:  [0.32 0.39 0.29]
# (1, 1) probas:  [0.48 0.31 0.21]
# (2, 0) probas:  [0.32 0.4  0.28]
# (2, 1) probas:  [0.48 0.32 0.2 ]
# (3, 0) probas:  [0.32 0.41 0.27]
# (3, 1) probas:  [0.48 0.33 0.2 ]
# (4, 0) probas:  [0.31 0.42 0.26]
# (4, 1) probas:  [0.47 0.34 0.2 ]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  11
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  12
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  13
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  14
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  15
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  16
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  17
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  18
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  19
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  20
# (0, 0) probas:  [0.38 0.28 0.34]
# (0, 1) probas:  [0.61 0.2  0.19]
# (1, 0) probas:  [0.37 0.3  0.34]
# (1, 1) probas:  [0.63 0.2  0.18]
# (2, 0) probas:  [0.37 0.31 0.32]
# (2, 1) probas:  [0.64 0.2  0.17]
# (3, 0) probas:  [0.37 0.32 0.31]
# (3, 1) probas:  [0.64 0.2  0.16]
# (4, 0) probas:  [0.37 0.33 0.29]
# (4, 1) probas:  [0.64 0.2  0.16]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  21
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  22
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  23
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  24
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  25
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  26
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  27
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  28
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  29
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  30
# (0, 0) probas:  [0.25 0.34 0.41]
# (0, 1) probas:  [0.49 0.21 0.3 ]
# (1, 0) probas:  [0.22 0.37 0.4 ]
# (1, 1) probas:  [0.5  0.21 0.29]
# (2, 0) probas:  [0.21 0.4  0.39]
# (2, 1) probas:  [0.49 0.22 0.29]
# (3, 0) probas:  [0.2  0.42 0.38]
# (3, 1) probas:  [0.46 0.25 0.29]
# (4, 0) probas:  [0.19 0.45 0.36]
# (4, 1) probas:  [0.44 0.27 0.29]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  31
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  32
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  33
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  34
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  35
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  36
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  37
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  38
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  39
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  40
# (0, 0) probas:  [0.25 0.34 0.41]
# (0, 1) probas:  [0.72 0.11 0.17]
# (1, 0) probas:  [0.23 0.39 0.39]
# (1, 1) probas:  [0.75 0.1  0.15]
# (2, 0) probas:  [0.23 0.42 0.35]
# (2, 1) probas:  [0.77 0.1  0.13]
# (3, 0) probas:  [0.23 0.45 0.32]
# (3, 1) probas:  [0.77 0.11 0.13]
# (4, 0) probas:  [0.24 0.47 0.3 ]
# (4, 1) probas:  [0.76 0.12 0.12]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  41
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  42
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  43
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  44
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  45
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  46
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  47
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  48
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  49
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  50
# (0, 0) probas:  [0.38 0.21 0.41]
# (0, 1) probas:  [0.9  0.03 0.07]
# (1, 0) probas:  [0.37 0.24 0.39]
# (1, 1) probas:  [0.91 0.03 0.06]
# (2, 0) probas:  [0.36 0.27 0.37]
# (2, 1) probas:  [0.93 0.03 0.05]
# (3, 0) probas:  [0.37 0.3  0.33]
# (3, 1) probas:  [0.93 0.03 0.04]
# (4, 0) probas:  [0.38 0.32 0.3 ]
# (4, 1) probas:  [0.94 0.03 0.04]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  51
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  52
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  53
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  54
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  55
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  56
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  57
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  58
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  59
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  60
# (0, 0) probas:  [0.23 0.19 0.58]
# (0, 1) probas:  [0.84 0.03 0.12]
# (1, 0) probas:  [0.2  0.21 0.59]
# (1, 1) probas:  [0.87 0.03 0.1 ]
# (2, 0) probas:  [0.19 0.25 0.55]
# (2, 1) probas:  [0.89 0.03 0.09]
# (3, 0) probas:  [0.2  0.29 0.51]
# (3, 1) probas:  [0.9  0.03 0.08]
# (4, 0) probas:  [0.21 0.32 0.47]
# (4, 1) probas:  [0.9  0.03 0.07]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  61
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  62
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  63
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  64
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  65
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  66
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  67
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  68
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  69
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  70
# (0, 0) probas:  [0.27 0.23 0.5 ]
# (0, 1) probas:  [0.89 0.03 0.08]
# (1, 0) probas:  [0.23 0.29 0.48]
# (1, 1) probas:  [0.91 0.02 0.07]
# (2, 0) probas:  [0.21 0.37 0.42]
# (2, 1) probas:  [0.92 0.02 0.06]
# (3, 0) probas:  [0.19 0.46 0.35]
# (3, 1) probas:  [0.92 0.03 0.05]
# (4, 0) probas:  [0.18 0.52 0.3 ]
# (4, 1) probas:  [0.91 0.04 0.05]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  71
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  72
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  73
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  74
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  75
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  76
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  77
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  78
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  79
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  80
# (0, 0) probas:  [0.2  0.26 0.54]
# (0, 1) probas:  [0.89 0.03 0.08]
# (1, 0) probas:  [0.16 0.36 0.48]
# (1, 1) probas:  [0.91 0.03 0.06]
# (2, 0) probas:  [0.14 0.47 0.39]
# (2, 1) probas:  [0.91 0.04 0.05]
# (3, 0) probas:  [0.13 0.57 0.3 ]
# (3, 1) probas:  [0.9  0.05 0.05]
# (4, 0) probas:  [0.12 0.64 0.24]
# (4, 1) probas:  [0.88 0.08 0.05]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  81
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  82
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  83
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  84
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  85
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  86
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  87
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  88
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  89
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  90
# (0, 0) probas:  [0.23 0.24 0.54]
# (0, 1) probas:  [0.92 0.02 0.06]
# (1, 0) probas:  [0.2  0.35 0.45]
# (1, 1) probas:  [0.93 0.02 0.04]
# (2, 0) probas:  [0.18 0.49 0.34]
# (2, 1) probas:  [0.94 0.02 0.04]
# (3, 0) probas:  [0.16 0.6  0.24]
# (3, 1) probas:  [0.94 0.03 0.03]
# (4, 0) probas:  [0.15 0.67 0.18]
# (4, 1) probas:  [0.92 0.05 0.03]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  91
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  92
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  93
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  94
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  95
# Score: 50
# % of visited states: 100.0%
# Iteration:  96
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  97
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  98
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  99
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  100
# (0, 0) probas:  [0.21 0.31 0.48]
# (0, 1) probas:  [0.94 0.02 0.04]
# (1, 0) probas:  [0.16 0.44 0.4 ]
# (1, 1) probas:  [0.95 0.02 0.03]
# (2, 0) probas:  [0.12 0.58 0.3 ]
# (2, 1) probas:  [0.95 0.02 0.03]
# (3, 0) probas:  [0.1  0.68 0.22]
# (3, 1) probas:  [0.95 0.03 0.02]
# (4, 0) probas:  [0.09 0.75 0.16]
# (4, 1) probas:  [0.93 0.05 0.02]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  101
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  102
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  103
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  104
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  105
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  106
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  107
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  108
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  109
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  110
# (0, 0) probas:  [0.17 0.27 0.56]
# (0, 1) probas:  [0.96 0.01 0.03]
# (1, 0) probas:  [0.14 0.39 0.47]
# (1, 1) probas:  [0.97 0.01 0.02]
# (2, 0) probas:  [0.12 0.53 0.35]
# (2, 1) probas:  [0.97 0.01 0.02]
# (3, 0) probas:  [0.11 0.65 0.25]
# (3, 1) probas:  [0.97 0.02 0.01]
# (4, 0) probas:  [0.1  0.73 0.17]
# (4, 1) probas:  [0.96 0.02 0.01]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  111
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  112
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  113
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  114
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  115
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  116
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  117
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  118
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  119
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  120
# (0, 0) probas:  [0.13 0.4  0.47]
# (0, 1) probas:  [0.91 0.04 0.05]
# (1, 0) probas:  [0.1  0.56 0.34]
# (1, 1) probas:  [0.91 0.05 0.04]
# (2, 0) probas:  [0.07 0.72 0.21]
# (2, 1) probas:  [0.89 0.08 0.03]
# (3, 0) probas:  [0.05 0.82 0.12]
# (3, 1) probas:  [0.84 0.13 0.03]
# (4, 0) probas:  [0.04 0.89 0.07]
# (4, 1) probas:  [0.76 0.22 0.02]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  121
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  122
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  123
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  124
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  125
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  126
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  127
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  128
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  129
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  130
# (0, 0) probas:  [0.17 0.21 0.62]
# (0, 1) probas:  [0.95 0.01 0.04]
# (1, 0) probas:  [0.14 0.3  0.56]
# (1, 1) probas:  [0.96 0.01 0.03]
# (2, 0) probas:  [0.12 0.45 0.43]
# (2, 1) probas:  [0.96 0.02 0.02]
# (3, 0) probas:  [0.1 0.6 0.3]
# (3, 1) probas:  [0.96 0.02 0.02]
# (4, 0) probas:  [0.09 0.72 0.19]
# (4, 1) probas:  [0.95 0.03 0.02]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  131
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  132
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  133
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  134
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  135
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  136
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  137
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  138
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  139
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  140
# (0, 0) probas:  [0.14 0.23 0.64]
# (0, 1) probas:  [0.93 0.02 0.05]
# (1, 0) probas:  [0.1  0.33 0.56]
# (1, 1) probas:  [0.95 0.02 0.03]
# (2, 0) probas:  [0.09 0.51 0.4 ]
# (2, 1) probas:  [0.95 0.03 0.03]
# (3, 0) probas:  [0.07 0.68 0.25]
# (3, 1) probas:  [0.93 0.04 0.02]
# (4, 0) probas:  [0.05 0.8  0.15]
# (4, 1) probas:  [0.9  0.07 0.02]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  141
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  142
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  143
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  144
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  145
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  146
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  147
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  148
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  149
# Score: 50
# % of visited states: 100.0%
#
# ****************************************************************************************************
# TRAINING ENDED

# %%
plot_scores(agent.scores, window_size=100)
agent.get_policy()
plot_policy(env, agent.pi, "REINFORCE Seq Count")
plot_state_freq(agent.state_freq)
agent.get_proba()
agent.get_space_visitation()
# Out:
# 100.0

# %% [markdown]
# ### Reinforce count staes + seq exploration

# %%
from rl_research.algorithms.reinforce_count_seq_states import train

# %%
agent = train(env, L, logs=logs)
# Out:
# ****************************************************************************************************
# TRAINING START
#
#
# Iteration:  0
# (0, 0) probas:  [0.33 0.33 0.33]
# (0, 1) probas:  [0.36 0.31 0.33]
# (1, 0) probas:  [0.34 0.33 0.33]
# (1, 1) probas:  [0.36 0.3  0.34]
# (2, 0) probas:  [0.34 0.32 0.34]
# (2, 1) probas:  [0.36 0.29 0.35]
# (3, 0) probas:  [0.35 0.32 0.34]
# (3, 1) probas:  [0.36 0.29 0.36]
# (4, 0) probas:  [0.35 0.31 0.34]
# (4, 1) probas:  [0.35 0.28 0.36]
# Score: 0
# % of visited states: 40.0%
#
# Iteration:  1
# Score: 0
# % of visited states: 40.0%
#
# Iteration:  2
# Score: 0
# % of visited states: 50.0%
#
# Iteration:  3
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  4
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  5
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  6
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  7
# Score: 0
# % of visited states: 70.0%
#
# Iteration:  8
# Score: 50
# % of visited states: 80.0%
#
# Iteration:  9
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  10
# (0, 0) probas:  [0.35 0.3  0.35]
# (0, 1) probas:  [0.42 0.25 0.32]
# (1, 0) probas:  [0.36 0.28 0.36]
# (1, 1) probas:  [0.43 0.24 0.33]
# (2, 0) probas:  [0.37 0.27 0.36]
# (2, 1) probas:  [0.43 0.23 0.34]
# (3, 0) probas:  [0.38 0.26 0.36]
# (3, 1) probas:  [0.44 0.22 0.34]
# (4, 0) probas:  [0.39 0.25 0.36]
# (4, 1) probas:  [0.44 0.21 0.35]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  11
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  12
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  13
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  14
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  15
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  16
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  17
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  18
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  19
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  20
# (0, 0) probas:  [0.35 0.3  0.35]
# (0, 1) probas:  [0.42 0.25 0.32]
# (1, 0) probas:  [0.36 0.28 0.36]
# (1, 1) probas:  [0.43 0.24 0.33]
# (2, 0) probas:  [0.37 0.27 0.36]
# (2, 1) probas:  [0.44 0.23 0.34]
# (3, 0) probas:  [0.38 0.26 0.36]
# (3, 1) probas:  [0.44 0.22 0.34]
# (4, 0) probas:  [0.39 0.25 0.36]
# (4, 1) probas:  [0.44 0.21 0.35]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  21
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  22
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  23
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  24
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  25
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  26
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  27
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  28
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  29
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  30
# (0, 0) probas:  [0.33 0.32 0.35]
# (0, 1) probas:  [0.43 0.28 0.29]
# (1, 0) probas:  [0.33 0.32 0.35]
# (1, 1) probas:  [0.44 0.27 0.29]
# (2, 0) probas:  [0.34 0.31 0.34]
# (2, 1) probas:  [0.45 0.27 0.29]
# (3, 0) probas:  [0.36 0.31 0.34]
# (3, 1) probas:  [0.45 0.26 0.29]
# (4, 0) probas:  [0.37 0.3  0.33]
# (4, 1) probas:  [0.46 0.25 0.29]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  31
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  32
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  33
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  34
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  35
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  36
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  37
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  38
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  39
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  40
# (0, 0) probas:  [0.32 0.33 0.35]
# (0, 1) probas:  [0.44 0.3  0.26]
# (1, 0) probas:  [0.31 0.34 0.35]
# (1, 1) probas:  [0.46 0.29 0.26]
# (2, 0) probas:  [0.31 0.34 0.35]
# (2, 1) probas:  [0.46 0.28 0.26]
# (3, 0) probas:  [0.32 0.34 0.34]
# (3, 1) probas:  [0.47 0.27 0.26]
# (4, 0) probas:  [0.32 0.34 0.34]
# (4, 1) probas:  [0.47 0.27 0.26]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  41
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  42
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  43
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  44
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  45
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  46
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  47
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  48
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  49
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  50
# (0, 0) probas:  [0.28 0.33 0.38]
# (0, 1) probas:  [0.61 0.22 0.17]
# (1, 0) probas:  [0.28 0.34 0.38]
# (1, 1) probas:  [0.63 0.2  0.17]
# (2, 0) probas:  [0.28 0.35 0.37]
# (2, 1) probas:  [0.65 0.19 0.16]
# (3, 0) probas:  [0.29 0.35 0.36]
# (3, 1) probas:  [0.66 0.18 0.15]
# (4, 0) probas:  [0.3  0.35 0.35]
# (4, 1) probas:  [0.66 0.18 0.15]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  51
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  52
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  53
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  54
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  55
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  56
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  57
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  58
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  59
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  60
# (0, 0) probas:  [0.23 0.35 0.42]
# (0, 1) probas:  [0.63 0.2  0.17]
# (1, 0) probas:  [0.22 0.35 0.43]
# (1, 1) probas:  [0.66 0.19 0.15]
# (2, 0) probas:  [0.22 0.35 0.43]
# (2, 1) probas:  [0.68 0.17 0.14]
# (3, 0) probas:  [0.23 0.35 0.42]
# (3, 1) probas:  [0.7  0.16 0.14]
# (4, 0) probas:  [0.24 0.35 0.41]
# (4, 1) probas:  [0.7  0.16 0.14]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  61
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  62
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  63
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  64
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  65
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  66
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  67
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  68
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  69
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  70
# (0, 0) probas:  [0.19 0.39 0.43]
# (0, 1) probas:  [0.66 0.19 0.15]
# (1, 0) probas:  [0.17 0.4  0.43]
# (1, 1) probas:  [0.69 0.17 0.14]
# (2, 0) probas:  [0.16 0.42 0.42]
# (2, 1) probas:  [0.71 0.16 0.12]
# (3, 0) probas:  [0.16 0.44 0.4 ]
# (3, 1) probas:  [0.72 0.16 0.12]
# (4, 0) probas:  [0.16 0.45 0.38]
# (4, 1) probas:  [0.71 0.17 0.12]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  71
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  72
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  73
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  74
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  75
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  76
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  77
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  78
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  79
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  80
# (0, 0) probas:  [0.16 0.39 0.45]
# (0, 1) probas:  [0.65 0.2  0.16]
# (1, 0) probas:  [0.14 0.39 0.46]
# (1, 1) probas:  [0.68 0.18 0.14]
# (2, 0) probas:  [0.14 0.41 0.46]
# (2, 1) probas:  [0.71 0.17 0.13]
# (3, 0) probas:  [0.14 0.43 0.43]
# (3, 1) probas:  [0.73 0.16 0.12]
# (4, 0) probas:  [0.14 0.44 0.41]
# (4, 1) probas:  [0.73 0.16 0.11]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  81
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  82
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  83
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  84
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  85
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  86
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  87
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  88
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  89
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  90
# (0, 0) probas:  [0.25 0.37 0.38]
# (0, 1) probas:  [0.85 0.09 0.06]
# (1, 0) probas:  [0.28 0.38 0.34]
# (1, 1) probas:  [0.88 0.08 0.04]
# (2, 0) probas:  [0.33 0.39 0.29]
# (2, 1) probas:  [0.9  0.06 0.03]
# (3, 0) probas:  [0.38 0.38 0.24]
# (3, 1) probas:  [0.92 0.05 0.03]
# (4, 0) probas:  [0.44 0.37 0.19]
# (4, 1) probas:  [0.93 0.05 0.02]
# Score: 0
# % of visited states: 100.0%
# Iteration:  91
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  92
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  93
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  94
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  95
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  96
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  97
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  98
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  99
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  100
# (0, 0) probas:  [0.19 0.38 0.43]
# (0, 1) probas:  [0.82 0.1  0.07]
# (1, 0) probas:  [0.18 0.39 0.42]
# (1, 1) probas:  [0.86 0.08 0.06]
# (2, 0) probas:  [0.21 0.41 0.38]
# (2, 1) probas:  [0.88 0.07 0.05]
# (3, 0) probas:  [0.25 0.42 0.33]
# (3, 1) probas:  [0.9  0.06 0.04]
# (4, 0) probas:  [0.29 0.42 0.28]
# (4, 1) probas:  [0.92 0.05 0.03]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  101
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  102
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  103
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  104
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  105
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  106
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  107
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  108
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  109
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  110
# (0, 0) probas:  [0.14 0.39 0.47]
# (0, 1) probas:  [0.88 0.06 0.05]
# (1, 0) probas:  [0.13 0.41 0.46]
# (1, 1) probas:  [0.91 0.05 0.04]
# (2, 0) probas:  [0.14 0.44 0.42]
# (2, 1) probas:  [0.93 0.04 0.03]
# (3, 0) probas:  [0.18 0.45 0.37]
# (3, 1) probas:  [0.95 0.03 0.02]
# (4, 0) probas:  [0.23 0.46 0.31]
# (4, 1) probas:  [0.96 0.03 0.02]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  111
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  112
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  113
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  114
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  115
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  116
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  117
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  118
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  119
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  120
# (0, 0) probas:  [0.16 0.41 0.43]
# (0, 1) probas:  [0.92 0.05 0.03]
# (1, 0) probas:  [0.15 0.45 0.4 ]
# (1, 1) probas:  [0.94 0.04 0.02]
# (2, 0) probas:  [0.19 0.49 0.32]
# (2, 1) probas:  [0.95 0.03 0.01]
# (3, 0) probas:  [0.25 0.51 0.24]
# (3, 1) probas:  [0.97 0.02 0.01]
# (4, 0) probas:  [0.32 0.5  0.18]
# (4, 1) probas:  [0.97 0.02 0.01]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  121
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  122
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  123
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  124
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  125
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  126
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  127
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  128
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  129
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  130
# (0, 0) probas:  [0.14 0.37 0.5 ]
# (0, 1) probas:  [0.92 0.04 0.03]
# (1, 0) probas:  [0.13 0.38 0.49]
# (1, 1) probas:  [0.95 0.03 0.02]
# (2, 0) probas:  [0.14 0.42 0.44]
# (2, 1) probas:  [0.96 0.02 0.01]
# (3, 0) probas:  [0.19 0.45 0.36]
# (3, 1) probas:  [0.97 0.02 0.01]
# (4, 0) probas:  [0.26 0.46 0.28]
# (4, 1) probas:  [0.98 0.02 0.01]
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  131
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  132
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  133
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  134
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  135
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  136
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  137
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  138
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  139
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  140
# (0, 0) probas:  [0.16 0.4  0.44]
# (0, 1) probas:  [0.94 0.04 0.02]
# (1, 0) probas:  [0.16 0.45 0.39]
# (1, 1) probas:  [0.96 0.03 0.01]
# (2, 0) probas:  [0.21 0.5  0.29]
# (2, 1) probas:  [0.97 0.02 0.01]
# (3, 0) probas:  [0.29 0.51 0.2 ]
# (3, 1) probas:  [0.98 0.01 0.  ]
# (4, 0) probas:  [0.38 0.49 0.14]
# (4, 1) probas:  [0.99 0.01 0.  ]
# Score: 0
# % of visited states: 100.0%
#
# Iteration:  141
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  142
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  143
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  144
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  145
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  146
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  147
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  148
# Score: 50
# % of visited states: 100.0%
#
# Iteration:  149
# Score: 50
# % of visited states: 100.0%
#
# ****************************************************************************************************
# TRAINING ENDED

# %%
plot_scores(agent.scores)
agent.get_policy()
plot_policy(env, agent.pi, "REINFORCE Seq Count")
plot_state_freq(agent.state_freq)
agent.get_proba()
# Out:
# 100.0

# %% [markdown]
# ### NS ES

# %%
# from NS_ES import train

# %%
# agent = train(env)

# %% [markdown]
# ### QD ES

# %%
# npop = 40
# alpha = 0.1
# sigma = 1
# generation = 100

# K = 3
# archive = set()
# while len(archive) != K:
#     archive.add(QD_Agent().get_bc(env))

# agent = QD_Agent()


# print("\n"+"*"*100)
# print("TRAINING START\n")

# for gen in range(generation):
#     new_agents, N = create_pop(agent, npop=npop, sigma=sigma)
#     F = np.zeros(npop)
#     D = []
    
#     for i, n_a in enumerate(new_agents):
#         F[i] = n_a.evaluate(env)
#         D.append(n_a.get_bc(env)) 
    
# #     print(R)
    
#     nbrs = NearestNeighbors(n_neighbors=K, algorithm='ball_tree').fit(np.array(list(archive)))
#     D = np.mean(nbrs.kneighbors(np.array(R))[0], axis=1)

#     R = normalize_array(F) + normalize_array(D)
    
#     if np.std(R) == 0:
#         A = np.zeros(npop)
#     else:
#         A = (R - np.mean(R)) / np.std(R)
        
#     for key in agent.weights:
#         agent.weights[key] += alpha/(npop*sigma) * (N[key] @ A)
    
#     archive.add(agent.get_bc(env))
#     print(archive)
# #     print(agent.weights['w1'][0])
    
# #     print("Generation:", gen, "Score:", print(F))

# print("\n"+"*"*100)
# print("TRAINING ENDED\n")

# %%
res_r = pd.read_csv('data/reinforce_res.csv')
res_r_seq = pd.read_csv('data/reinforce_res_seq.csv')
res_r_st = pd.read_csv('data/reinforce_res_st.csv')

# %%
np.sum(res_r_st > 49)>0

# %%
np.sum(res_r_seq > 49)>0
